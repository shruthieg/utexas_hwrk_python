# %%
#Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
temp = []
Humid = [] 
Cloudy = []
Wind_Speed = []
Lat = []
foundcities = []
Date = []


for city in cities:
    params = {
        'appid' : api_key,
        'q' : city,
        'units' : 'imperal'
    }
    print(" finding weather for " +city)
    try:
        response = requests.get(url, params=params).json()
        Lat.append(response['coord']['lat'])
        temp.append(response['main']['temp_max'])
        Humid.append(response['main']['humidity'])
        Cloudy.append(response['clouds']['all'])
        Wind_Speed.append(response['wind']['speed'])
        foundcities.append(response['name'])
        print("found")
    except KeyError:
        print("City " + city + " not found")

    
#print(f"The latitude information received is: {lat}")
#print(f"The temperature information received is: {temp}")


#Build a scatter plot for each data type
plt.scatter(response['lat'],response['temp'], marker="o", color = 'blue')

# # Incorporate the other graph properties
plt.title("City Altitude vs Max Temperature ")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.yticks(np.arange(-40, 120, 20))
plt.grid(True)
sns.set_style('darkgrid')

# # Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()
# Out:
#  finding weather for thompson
# found
#  finding weather for saskylakh
# found
#  finding weather for ancud
# found
#  finding weather for vilyuysk
# found
#  finding weather for punta arenas
# found
#  finding weather for butaritari
# found
#  finding weather for taolanaro
# City taolanaro not found
#  finding weather for nagpur
# found
#  finding weather for khatanga
# found
#  finding weather for douglas
# found
#  finding weather for busselton
# found
#  finding weather for berestechko
# found
#  finding weather for puerto carreno
# found
#  finding weather for cape town
# found
#  finding weather for atuona
# found
#  finding weather for hermanus
# found
#  finding weather for georgetown
# found
#  finding weather for east london
# found
#  finding weather for dongsheng
# found
#  finding weather for kodiak
# found
#  finding weather for new norfolk
# found
#  finding weather for stillwater
# found
#  finding weather for saint-philippe
# found
#  finding weather for paamiut
# found
#  finding weather for pevek
# found
#  finding weather for asau
# City asau not found
#  finding weather for longyearbyen
# found
#  finding weather for ornskoldsvik
# found
#  finding weather for fortuna
# found
#  finding weather for pitimbu
# found
#  finding weather for clyde river
# found
#  finding weather for porto santo
# City porto santo not found
#  finding weather for arraial do cabo
# found
#  finding weather for san policarpo
# found
#  finding weather for amderma
# City amderma not found
#  finding weather for tasiilaq
# found
#  finding weather for mataura
# found
#  finding weather for hithadhoo
# found
#  finding weather for zhangye
# found
#  finding weather for karaul
# City karaul not found
#  finding weather for belushya guba
# City belushya guba not found
#  finding weather for namatanai
# found
#  finding weather for manicore
# found
#  finding weather for povenets
# found
#  finding weather for sola
# found
#  finding weather for vardo
# found
#  finding weather for barrow
# found
#  finding weather for bluff
# found
#  finding weather for san patricio
# found
#  finding weather for shimonoseki
# found
#  finding weather for bethel
# found
#  finding weather for mount isa
# found
#  finding weather for bathsheba
# found
#  finding weather for port alfred
# found
#  finding weather for sao joao da barra
# found
#  finding weather for hobyo
# found
#  finding weather for pundaguitan
# found
#  finding weather for ngukurr
# City ngukurr not found
#  finding weather for freeport
# found
#  finding weather for puerto ayora
# found
#  finding weather for jieshi
# found
#  finding weather for lima
# found
#  finding weather for geresk
# City geresk not found
#  finding weather for mosquera
# found
#  finding weather for blackwater
# found
#  finding weather for lata
# found
#  finding weather for ugoofaaru
# found
#  finding weather for vaitupu
# City vaitupu not found
#  finding weather for barentsburg
# City barentsburg not found
#  finding weather for hobart
# found
#  finding weather for angra
# City angra not found
#  finding weather for chauk
# found
#  finding weather for jamestown
# found
#  finding weather for mahebourg
# found
#  finding weather for ushuaia
# found
#  finding weather for mount gambier
# found
#  finding weather for rikitea
# found
#  finding weather for luderitz
# found
#  finding weather for hilo
# found
#  finding weather for tuktoyaktuk
# found
#  finding weather for kapaa
# found
#  finding weather for saint anthony
# found
#  finding weather for victor harbor
# found
#  finding weather for richards bay
# found
#  finding weather for lhuntshi
# City lhuntshi not found
#  finding weather for airai
# found
#  finding weather for bredasdorp
# found
#  finding weather for mareeba
# found
#  finding weather for vila velha
# found
#  finding weather for upernavik
# found
#  finding weather for samusu
# City samusu not found
#  finding weather for tessalit
# found
#  finding weather for gondar
# found
#  finding weather for souillac
# found
#  finding weather for norman wells
# found
#  finding weather for antigonish
# found
#  finding weather for yerbogachen
# found
#  finding weather for trairi
# found
#  finding weather for dikson
# found
#  finding weather for illoqqortoormiut
# City illoqqortoormiut not found
#  finding weather for baykit
# found
#  finding weather for albany
# found
#  finding weather for tumannyy
# City tumannyy not found
#  finding weather for te anau
# found
#  finding weather for ngunguru
# found
#  finding weather for port lincoln
# found
#  finding weather for menongue
# found
#  finding weather for narsaq
# found
#  finding weather for shingu
# found
#  finding weather for owensboro
# found
#  finding weather for victoria
# found
#  finding weather for pisco
# found
#  finding weather for tsihombe
# City tsihombe not found
#  finding weather for sofiysk
# City sofiysk not found
#  finding weather for katsuura
# found
#  finding weather for port elizabeth
# found
#  finding weather for svobodnyy
# found
#  finding weather for reconquista
# found
#  finding weather for mar del plata
# found
#  finding weather for marcona
# City marcona not found
#  finding weather for kavieng
# found
#  finding weather for ixtapa
# found
#  finding weather for mys shmidta
# City mys shmidta not found
#  finding weather for jurilovca
# found
#  finding weather for kalmunai
# found
#  finding weather for nanortalik
# found
#  finding weather for husavik
# found
#  finding weather for mayo
# found
#  finding weather for letlhakane
# found
#  finding weather for liangxiang
# found
#  finding weather for kununurra
# found
#  finding weather for maceio
# found
#  finding weather for zhigalovo
# found
#  finding weather for tateyama
# found
#  finding weather for belmonte
# found
#  finding weather for guarapari
# found
#  finding weather for madang
# found
#  finding weather for harper
# found
#  finding weather for provideniya
# found
#  finding weather for nara
# found
#  finding weather for japura
# found
#  finding weather for nome
# found
#  finding weather for broome
# found
#  finding weather for bulgan
# found
#  finding weather for nizwa
# found
#  finding weather for riohacha
# found
#  finding weather for saint george
# found
#  finding weather for lakatoro
# found
#  finding weather for siparia
# found
#  finding weather for teguldet
# found
#  finding weather for roma
# found
#  finding weather for yellowknife
# found
#  finding weather for ribeira grande
# found
#  finding weather for labytnangi
# found
#  finding weather for ramnagar
# found
#  finding weather for torbay
# found
#  finding weather for solton
# found
#  finding weather for burnie
# found
#  finding weather for san quintin
# found
#  finding weather for hearst
# found
#  finding weather for vaini
# found
#  finding weather for labutta
# City labutta not found
#  finding weather for taicheng
# found
#  finding weather for ilulissat
# found
#  finding weather for avarua
# found
#  finding weather for doha
# found
#  finding weather for sedelnikovo
# City sedelnikovo not found
#  finding weather for kampong chhnang
# found
#  finding weather for hambantota
# found
#  finding weather for constitucion
# found
#  finding weather for nikolskoye
# found
#  finding weather for staraya mayna
# found
#  finding weather for mecca
# found
#  finding weather for touros
# found
#  finding weather for salalah
# found
#  finding weather for panguna
# found
#  finding weather for nacogdoches
# found
#  finding weather for honiara
# found
#  finding weather for namwala
# found
#  finding weather for galgani
# City galgani not found
#  finding weather for carnarvon
# found
#  finding weather for zlitan
# found
#  finding weather for portland
# found
#  finding weather for evensk
# found
#  finding weather for gashua
# found
#  finding weather for arlit
# found
#  finding weather for hami
# found
#  finding weather for sorong
# found
#  finding weather for lorengau
# found
#  finding weather for huarmey
# found
#  finding weather for baran
# found
#  finding weather for colac
# found
#  finding weather for acapulco
# found
#  finding weather for olafsvik
# City olafsvik not found
#  finding weather for okato
# found
#  finding weather for geraldton
# found
#  finding weather for hay river
# found
#  finding weather for camopi
# found
#  finding weather for mulege
# found
#  finding weather for danjiangkou
# found
#  finding weather for providencia
# found
#  finding weather for teknaf
# found
#  finding weather for umm lajj
# found
#  finding weather for qaanaaq
# found
#  finding weather for codrington
# found
#  finding weather for qobustan
# found
#  finding weather for ostrovnoy
# found
#  finding weather for sumbe
# found
#  finding weather for coquimbo
# found
#  finding weather for grand gaube
# found
#  finding weather for itarema
# found
#  finding weather for chokwe
# City chokwe not found
#  finding weather for ponta do sol
# found
#  finding weather for berlevag
# found
#  finding weather for eyl
# found
#  finding weather for ust-tsilma
# found
#  finding weather for pangoa
# found
#  finding weather for faya
# found
#  finding weather for chuy
# found
#  finding weather for cabo san lucas
# found
#  finding weather for tooele
# found
#  finding weather for cam ranh
# found
#  finding weather for maniitsoq
# found
#  finding weather for hofn
# found
#  finding weather for tiksi
# found
#  finding weather for cayenne
# found
#  finding weather for hamilton
# found
#  finding weather for mehamn
# found
#  finding weather for sosua
# found
#  finding weather for nyurba
# found
#  finding weather for eucaliptus
# found
#  finding weather for yulara
# found
#  finding weather for chicama
# found
#  finding weather for khor
# found
#  finding weather for sinop
# found
#  finding weather for san carlos
# found
#  finding weather for puerto lopez
# City puerto lopez not found
#  finding weather for umzimvubu
# City umzimvubu not found
#  finding weather for brainerd
# found
#  finding weather for grand river south east
# City grand river south east not found
#  finding weather for kloulklubed
# found
#  finding weather for klaksvik
# found
#  finding weather for ozernovskiy
# found
#  finding weather for popondetta
# found
#  finding weather for sarreguemines
# found
#  finding weather for atambua
# found
#  finding weather for lavrentiya
# found
#  finding weather for sitka
# found
#  finding weather for palmer
# found
#  finding weather for jiangyou
# found
#  finding weather for ghorawal
# found
#  finding weather for severo-kurilsk
# found
#  finding weather for ariquemes
# found
#  finding weather for bambanglipuro
# found
#  finding weather for mangrol
# found
#  finding weather for bambous virieux
# found
#  finding weather for cidreira
# found
#  finding weather for cherskiy
# found
#  finding weather for puerto ayacucho
# found
#  finding weather for saldanha
# found
#  finding weather for kijang
# found
#  finding weather for manakara
# found
#  finding weather for makakilo city
# found
#  finding weather for louisbourg
# City louisbourg not found
#  finding weather for pozo colorado
# found
#  finding weather for zyryanka
# found
#  finding weather for xichang
# found
#  finding weather for doctor pedro p. pena
# City doctor pedro p. pena not found
#  finding weather for sentyabrskiy
# City sentyabrskiy not found
#  finding weather for tonantins
# found
#  finding weather for bengbu
# found
#  finding weather for fare
# found
#  finding weather for owando
# found
#  finding weather for vestmannaeyjar
# found
#  finding weather for beringovskiy
# found
#  finding weather for yagodnoye
# found
#  finding weather for vila
# found
#  finding weather for atar
# found
#  finding weather for birao
# found
#  finding weather for yar-sale
# found
#  finding weather for kavarna
# found
#  finding weather for xudat
# found
#  finding weather for lasa
# found
#  finding weather for muisne
# found
#  finding weather for bekhtery
# found
#  finding weather for madimba
# found
#  finding weather for alice springs
# found
#  finding weather for port hardy
# found
#  finding weather for hirara
# found
#  finding weather for quang ngai
# found
#  finding weather for villanueva
# found
#  finding weather for bilma
# found
#  finding weather for sao filipe
# found
#  finding weather for bubaque
# found
#  finding weather for plaster rock
# found
#  finding weather for wiang sa
# found
#  finding weather for santo antonio do ica
# found
#  finding weather for mirnyy
# found
#  finding weather for mrirt
# City mrirt not found
#  finding weather for alofi
# found
#  finding weather for antsohihy
# found
#  finding weather for mabaruma
# found
#  finding weather for tura
# found
#  finding weather for chokurdakh
# found
#  finding weather for sault sainte marie
# found
#  finding weather for attawapiskat
# City attawapiskat not found
#  finding weather for tual
# found
#  finding weather for bintulu
# found
#  finding weather for lebu
# found
#  finding weather for diplo
# found
#  finding weather for bemidji
# found
#  finding weather for nelson bay
# found
#  finding weather for kaitangata
# found
#  finding weather for marsa matruh
# found
#  finding weather for omboue
# found
#  finding weather for kismayo
# City kismayo not found
#  finding weather for ambon
# found
#  finding weather for nurota
# found
#  finding weather for tres arroyos
# found
#  finding weather for hasaki
# found
#  finding weather for kiria
# found
#  finding weather for ignatovka
# found
#  finding weather for perelyub
# found
#  finding weather for fujin
# found
#  finding weather for yunjinghong
# City yunjinghong not found
#  finding weather for saint-pierre
# found
#  finding weather for okhotsk
# found
#  finding weather for luanda
# found
#  finding weather for laguna
# found
#  finding weather for mingaora
# found
#  finding weather for isangel
# found
#  finding weather for esperance
# found
#  finding weather for los llanos de aridane
# found
#  finding weather for gillette
# found
#  finding weather for korla
# City korla not found
#  finding weather for marawi
# found
#  finding weather for sibolga
# found
#  finding weather for faanui
# found
#  finding weather for peniche
# found
#  finding weather for zdunska wola
# found
#  finding weather for sakakah
# City sakakah not found
#  finding weather for suez
# found
#  finding weather for punta alta
# found
#  finding weather for jiexiu
# found
#  finding weather for port blair
# found
#  finding weather for council bluffs
# found
#  finding weather for nimaparha
# found
#  finding weather for leningradskiy
# found
#  finding weather for dingle
# found
#  finding weather for weihai
# found
#  finding weather for tabou
# found
#  finding weather for longlac
# City longlac not found
#  finding weather for karratha
# found
#  finding weather for camacha
# found
#  finding weather for santa cruz
# found
#  finding weather for tambo
# found
#  finding weather for ballina
# found
#  finding weather for la ronge
# found
#  finding weather for ahumada
# City ahumada not found
#  finding weather for bull savanna
# found
#  finding weather for hualmay
# found
#  finding weather for bonthe
# found
#  finding weather for scarborough
# found
#  finding weather for urumqi
# City urumqi not found
#  finding weather for svetlyy
# City svetlyy not found
#  finding weather for tazovskiy
# found
#  finding weather for ust-kan
# found
#  finding weather for castro
# found
#  finding weather for kieta
# found
#  finding weather for colombia
# found
#  finding weather for fort nelson
# found
#  finding weather for warri
# found
#  finding weather for bengkulu
# City bengkulu not found
#  finding weather for swan hill
# found
#  finding weather for wilmington island
# found
#  finding weather for verkhoyansk
# found
#  finding weather for pravdinskiy
# found
#  finding weather for yakeshi
# found
#  finding weather for umea
# found
#  finding weather for sao felix do xingu
# found
#  finding weather for srednekolymsk
# found
#  finding weather for carutapera
# found
#  finding weather for bapatla
# found
#  finding weather for litoral del san juan
# City litoral del san juan not found
#  finding weather for ibanda
# found
#  finding weather for marystown
# found
#  finding weather for tapes
# found
#  finding weather for otradnoye
# found
#  finding weather for mogadishu
# found
#  finding weather for kidal
# found
#  finding weather for parnamirim
# found
#  finding weather for sinnamary
# found
#  finding weather for tianmen
# found
#  finding weather for grand-lahou
# found
#  finding weather for walvis bay
# found
#  finding weather for moyale
# found
#  finding weather for paragominas
# found
#  finding weather for mikhaylovka
# found
#  finding weather for pascagoula
# found
#  finding weather for kirakira
# found
#  finding weather for skiros
# City skiros not found
#  finding weather for hargeysa
# found
#  finding weather for caarapo
# found
#  finding weather for outjo
# found
#  finding weather for brokopondo
# found
#  finding weather for cuiluan
# found
#  finding weather for qaqortoq
# found
#  finding weather for udachnyy
# found
#  finding weather for umuahia
# found
#  finding weather for high level
# found
#  finding weather for fort-shevchenko
# found
#  finding weather for san jeronimo
# found
#  finding weather for matay
# found
#  finding weather for egvekinot
# found
#  finding weather for alta floresta
# found
#  finding weather for takoradi
# found
#  finding weather for vanimo
# found
#  finding weather for baiao
# found
#  finding weather for kadykchan
# City kadykchan not found
#  finding weather for turbat
# found
#  finding weather for vila franca do campo
# found
#  finding weather for kenai
# found
#  finding weather for tahlequah
# found
#  finding weather for taoudenni
# found
#  finding weather for murray bridge
# found
#  finding weather for san jose
# found
#  finding weather for magadan
# found
#  finding weather for gat
# found
#  finding weather for mitsamiouli
# found
#  finding weather for grindavik
# found
#  finding weather for amboasary
# found
#  finding weather for havoysund
# found
#  finding weather for gurgan
# City gurgan not found
#  finding weather for nizhneyansk
# City nizhneyansk not found
#  finding weather for ketchikan
# found
#  finding weather for koppies
# found
#  finding weather for vastse-kuuste
# found
#  finding weather for chunhuhub
# found
#  finding weather for pervomaysk
# found
#  finding weather for senanga
# found
#  finding weather for jumla
# found
#  finding weather for talas
# found
#  finding weather for flinders
# found
#  finding weather for akdepe
# found
#  finding weather for shellbrook
# found
#  finding weather for san cristobal
# found
#  finding weather for port-cartier
# found
#  finding weather for aitape
# found
#  finding weather for tsuruga
# found
#  finding weather for tuatapere
# found
#  finding weather for adrar
# found
#  finding weather for aklavik
# found
#  finding weather for tarauaca
# found
#  finding weather for honningsvag
# found
#  finding weather for kerema
# found
#  finding weather for yabrud
# found
#  finding weather for agua verde
# found
#  finding weather for santa vitoria
# found
#  finding weather for atikokan
# found
#  finding weather for tongzhou
# found
#  finding weather for batemans bay
# found
#  finding weather for kommunisticheskiy
# found
#  finding weather for nisia floresta
# found
#  finding weather for lipin bor
# found
#  finding weather for urdzhar
# City urdzhar not found
#  finding weather for ambilobe
# found
#  finding weather for cortes
# found
#  finding weather for anloga
# found
#  finding weather for dzhusaly
# City dzhusaly not found
#  finding weather for labuan
# found
#  finding weather for fuzhou
# found
#  finding weather for lagoa
# found
#  finding weather for veraval
# found
#  finding weather for puerto leguizamo
# found
#  finding weather for panalingaan
# found
#  finding weather for cotonou
# found
#  finding weather for cabra
# found
#  finding weather for krasnoselkup
# City krasnoselkup not found
#  finding weather for ahipara
# found
#  finding weather for tikamgarh
# found
#  finding weather for deputatskiy
# found
#  finding weather for wuwei
# found
#  finding weather for mackay
# found
#  finding weather for machilipatnam
# found
#  finding weather for miracema do tocantins
# found
#  finding weather for sibu
# found
#  finding weather for belfast
# found
#  finding weather for damghan
# found
#  finding weather for jacareacanga
# found
#  finding weather for vilhena
# found
#  finding weather for santa cruz de la palma
# found
#  finding weather for olga
# found
#  finding weather for gushikawa
# found
#  finding weather for brookings
# found
#  finding weather for fallon
# found
#  finding weather for parras
# City parras not found
#  finding weather for teshie
# found
#  finding weather for damietta
# found
#  finding weather for tucurui
# found
#  finding weather for yangcun
# found
#  finding weather for lusambo
# found
#  finding weather for taksimo
# found
#  finding weather for ponta delgada
# found
#  finding weather for daoukro
# found
#  finding weather for loukhi
# found
#  finding weather for westport
# found
#  finding weather for gizo
# found
#  finding weather for nemuro
# found
#  finding weather for zachagansk
# City zachagansk not found
#  finding weather for dubuque
# found
#  finding weather for trinidad
# found
#  finding weather for yanan
# City yanan not found
#  finding weather for christchurch
# found
#  finding weather for kruisfontein
# found
#  finding weather for dong hoi
# found
#  finding weather for chagda
# City chagda not found
#  finding weather for saint-augustin
# found
#  finding weather for maloy
# found
#  finding weather for saleaula
# City saleaula not found
#  finding weather for iskateley
# found
#  finding weather for paredon
# found
#  finding weather for northam
# found
#  finding weather for marzuq
# found
#  finding weather for anchorage
# found
#  finding weather for macamic
# found
#  finding weather for orlik
# found
#  finding weather for college
# found
#  finding weather for karatuzskoye
# found
#  finding weather for atasu
# found
#  finding weather for georgiyevka
# found
#  finding weather for naze
# found
#  finding weather for ibatiba
# found
#  finding weather for yashkul
# found
#  finding weather for sayyan
# found
#  finding weather for tabas
# found
#  finding weather for kavaratti
# found
#  finding weather for florence
# found
#  finding weather for santa marta
# found
#  finding weather for najran
# found
#  finding weather for deniliquin
# found
#  finding weather for alberton
# found
#  finding weather for burica
# City burica not found
#  finding weather for ondarroa
# found
#  finding weather for sherbrooke
# found
#  finding weather for bijar
# found
#  finding weather for tromso
# found
#  finding weather for savelugu
# found
#  finding weather for aksarka
# found
#  finding weather for yarmouth
# found
#  finding weather for tilichiki
# found
#  finding weather for qandala
# found
#  finding weather for sarichioi
# found
#  finding weather for brza palanka
# found
#  finding weather for jizan
# found
#  finding weather for kondinskoye
# found
#  finding weather for boulder
# found
#  finding weather for hellvik
# found
#  finding weather for alyangula
# found
#  finding weather for hue
# found
#  finding weather for collie
# found
#  finding weather for gladstone
# found
#  finding weather for duz
# City duz not found
#  finding weather for buchanan
# found
#  finding weather for lompoc
# found
#  finding weather for eldikan
# City eldikan not found
#  finding weather for tocopilla
# found
#  finding weather for hokitika
# found
#  finding weather for port-gentil
# found
#  finding weather for slavsk
# found
#  finding weather for batagay-alyta
# found
#  finding weather for petatlan
# found
#  finding weather for sarankhola
# found
#  finding weather for isla vista
# found
#  finding weather for kudymkar
# found
#  finding weather for shimoda
# found
#  finding weather for aberdeen
# found
#  finding weather for maroantsetra
# found
#  finding weather for port augusta
# found
#  finding weather for inirida
# found
#  finding weather for boddam
# found
#  finding weather for nuuk
# found
#  finding weather for jaisalmer
# found
#  finding weather for manaure
# found
#  finding weather for meulaboh
# found
#  finding weather for ardrishaig
# found
#  finding weather for east foothills
# found
#  finding weather for koundara
# found
#  finding weather for san javier
# found
#  finding weather for rocha
# found
#  finding weather for puerto del rosario
# found
#  finding weather for chumikan
# found
#  finding weather for donja vrezina
# City donja vrezina not found
#  finding weather for sisimiut
# found
#  finding weather for riyadh
# found
#  finding weather for wanning
# found
#  finding weather for lengshuijiang
# found
#  finding weather for sur
# found
#  finding weather for hihifo
# City hihifo not found
#  finding weather for ylivieska
# found
#  finding weather for bang khla
# found
#  finding weather for mumford
# found
#  finding weather for manta
# found
#  finding weather for iralaya
# found
#  finding weather for sorvag
# City sorvag not found
#  finding weather for kiama
# found
#  finding weather for baruun-urt
# found
#  finding weather for port hedland
# found
#  finding weather for tucuman
# found
#  finding weather for ilinskiy
# found
#  finding weather for khaniotis
# found
#  finding weather for bowen
# found
#  finding weather for jardim
# found
#  finding weather for cascais
# found
#  finding weather for bozoum
# found
#  finding weather for starogard gdanski
# found
#  finding weather for nelson
# found
#  finding weather for falealupo
# City falealupo not found
#  finding weather for prince rupert
# found
#  finding weather for manokwari
# found
#  finding weather for matamoros
# found

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9fafd525ffc0> in <module>()
#       5     "temp": temp
#       6 }
# ----> 7 weather_data = pd.DataFrame(weather_dict)
#       8 weather_data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7313     # figure out the index, if necessary
#    7314     if index is None:
# -> 7315         index = extract_index(arrays)
#    7316
#    7317     # don't force copy because getting jammed in an ndarray anyway
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7359             lengths = list(set(raw_lengths))
#    7360             if len(lengths) > 1:
# -> 7361                 raise ValueError('arrays must all be same length')
#    7362
#    7363             if have_dicts:
#
# ValueError: arrays must all be same length
